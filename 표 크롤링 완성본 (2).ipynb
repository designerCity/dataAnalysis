# %%
# !pip install pandas
# !pip install html_table_parser

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from html_table_parser import parser_functions as parser

# %%
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver import ActionChains

# %%
# 첫 페이지 크롤링
import pandas as pd
from selenium.webdriver import ActionChains

result = urlopen(url)
html = result.read()
soup = BeautifulSoup(html,'html.parser')
a_tag = soup.findAll('a', href = True) 
# for i in a_tag:
#     print(i['href']) # 이 코드에서 살펴보고
# 페이지 이동 버튼만 추출
path = "/Users/kimsh/Downloads/chromedriver" # file 위치는 지정해줘야 한다.
driver = webdriver.Chrome(path)
url = "https://cps.or.kr/safe2/cps5sub1.jsp"
driver.get(url)

time.sleep(0.5)

# df = pd.DataFrame(sample,columns=['시설번호','시설명','설치장소', '주소', '상세'])
df = []
for j in range(1, 10): # 1 ~ 10 까지 페이지 넘기기
    ele = driver.find_element_by_xpath('/html/body/div/div[2]/div/div/div[2]/div[2]/div/table[5]/tbody/tr/td/a['+ str(j)+']')
    actions = ActionChains(driver)
    actions.move_to_element(ele)
    actions.click(on_element=ele)
    actions.perform()
    
    
    # 표 크롤링
    table = driver.find_element_by_class_name('table')
    tbody = table.find_element_by_tag_name("tbody")
    for i in range(10):
        rows = tbody.find_elements_by_tag_name("tr")[i] # 해당 row 들
        li = []
        for j in range(5):
            # body 는 셀레니움 리스트인 것 같다.
            body= rows.find_elements_by_tag_name("td")[j]      # row 에 해당하는 요소들
#             print(body.text)
            li.append(body.text)
#         print(li)
        df.append(li)
    
    
    
# 표 크롤링 데이터를 데이터 프레임으로 바꾸기
df = pd.DataFrame(df,columns=['시설번호','시설명','설치장소', '주소', '상세'])
df
# Out:
#       시설번호                               시설명    설치장소  \
# 0   585885      봉덕2차화성파크드림 커뮤니티센터 실내 어린이놀이시설    주택단지
# 1   585872               부천일루미스테이트 1단지 유아놀이터    주택단지
# 2   585871             부천일루미스테이트 1단지 어린이놀이터2    주택단지
# 3   585870             부천일루미스테이트 1단지 어린이놀이터1    주택단지
# 4   585834                          대한제국 삼호점  식품접객업소
# ..     ...                               ...     ...
# 85  585493                   백석초등학교병설유치원(실내)     유치원
# 86  585492          주안파크자이더플래티넘 312동 앞 유아놀이터    주택단지
# 87  585491        주안파크자이더플래티넘 309동 앞 어린이놀이터3    주택단지
# 88  585490  주안파크자이더플래티넘 308동 앞 어린이놀이터2(물놀이터)    주택단지
# 89  585489                여수봉산초등학교 학교숲 생태놀이터      학교
#
#                                            주소 상세
# 0        대구광역시 남구 봉덕동대구광역시 남구 봉덕동 1015 커뮤니티센터
# 1                             경기도 부천시 범박동49-3
# 2                             경기도 부천시 범박동49-3
# 3                             경기도 부천시 범박동49-3
# 4                    경상남도 양산시 삼호동부3길 17 (삼호동)
# ..                                        ... ..
# 85           전라북도 김제시 백산로 54 (흥사동)백석초등학교병설유치원
# 86  인천광역시 미추홀구 인하로222번길 20 (주안동, 주안파크자이더플래티넘)
# 87  인천광역시 미추홀구 인하로222번길 20 (주안동, 주안파크자이더플래티넘)
# 88  인천광역시 미추홀구 인하로222번길 20 (주안동, 주안파크자이더플래티넘)
# 89           전라남도 여수시 봉산새철4길 28 (봉산동)여수봉산초등학교
#
# [90 rows x 5 columns]

# %%
from selenium.webdriver import ActionChains

url = "https://cps.or.kr/safe2/cps5sub1.jsp"

# 페이지 이동 버튼만 추출
path = "/Users/kimsh/Downloads/chromedriver" # file 위치는 지정해줘야 한다.
driver = webdriver.Chrome(path)
driver.get(url)


df = []
# 다음 페이지로 넘어가게끔 (그래야 index 가 맞는다.)
ele = driver.find_element_by_xpath('/html/body/div/div[2]/div/div/div[2]/div[2]/div/table[5]/tbody/tr/td/a[10]')
actions = ActionChains(driver)
actions.move_to_element(ele)
actions.click(on_element=ele)
actions.perform()
for i in range(2): # 10 단위로 다음 페이지로 넘어가게끔 # range 안의 숫자는 10단위로 넘어가는 것
    time.sleep(0.5)
#     '/html/body/div.body/div.main/div.container/div.row/div.col-md-9/div.row/div.col-md-12/table/tbody/a[1]'
    for j in range(3, 13): # 10(i-1) + 1~10 까지
        ele = driver.find_element_by_xpath('/html/body/div/div[2]/div/div/div[2]/div[2]/div/table[5]/tbody/tr/td/a['+ str(j)+']')

        actions = ActionChains(driver)
        actions.move_to_element(ele)
        actions.click(on_element=ele)
        actions.perform()
        
        # 표 크롤링
        table = driver.find_element_by_class_name('table')
        tbody = table.find_element_by_tag_name("tbody")
        for i in range(10):
            rows = tbody.find_elements_by_tag_name("tr")[i] # 해당 row 들
            li = []
            for j in range(5):
                # body 는 셀레니움 리스트인 것 같다.
                body= rows.find_elements_by_tag_name("td")[j]      # row 에 해당하는 요소들
    #             print(body.text)
                li.append(body.text)
    #         print(li)
            df.append(li)

    
    
# 표 크롤링 데이터를 데이터 프레임으로 바꾸기
df = pd.DataFrame(df,columns=['시설번호','시설명','설치장소', '주소', '상세'])
df
# Out:
#        시설번호                         시설명     설치장소  \
# 0    585453  구월아시아드선수촌7단지 703동옆 어린이놀이터1     주택단지
# 1    585452    제일풍경채2차에듀 1329동 앞 어린이놀이터     주택단지
# 2    585451             도원어린이집 어린이놀이터 2     어린이집
# 3    585450             도원어린이집 어린이놀이터 1     어린이집
# 4    585448               임실둥지유치원 실내놀이터      유치원
# ..      ...                         ...      ...
# 195  585029               광성교회 키즈카페 놀이방     종교시설
# 196  585027             스타루루&윌리짐 실내놀이시설  놀이제공영업소
# 197  585026        천안청당 서희스타힐스 단지 유아놀이터     주택단지
# 198  585025      천안청당 서희스타힐스 단지 어린이놀이터2     주택단지
# 199  585024      천안청당 서희스타힐스 단지 어린이놀이터1     주택단지
#
#                                   주소 상세
# 0         인천광역시 남동구 구월동구월아시아드선수촌 7단지
# 1    경기도 평택시 고덕면 좌교리290 고덕제일풍경채 2차에듀
# 2            대구광역시 달성군 구지면 창리중앙2길 28
# 3            대구광역시 달성군 구지면 창리중앙2길 28
# 4      전라북도 임실군 임실읍 봉황7길 15-3임실둥지유치원
# ..                               ... ..
# 195         서울특별시 송파구 올림픽로 625 (풍납동)
# 196        경기도 광명시 일직로 17 (일직동)롯데몰2층
# 197            충청남도 천안시 동남구 청당동295-3
# 198            충청남도 천안시 동남구 청당동295-3
# 199            충청남도 천안시 동남구 청당동295-3
#
# [200 rows x 5 columns]

# %%
from selenium.webdriver import ActionChains


result = urlopen(url)
html = result.read()
soup = BeautifulSoup(html,'html.parser')
a_tag = soup.findAll('a', href = True) 
# for i in a_tag:
#     print(i['href']) # 이 코드에서 살펴보고
# 페이지 이동 버튼만 추출
path = "/Users/kimsh/Downloads/chromedriver" # file 위치는 지정해줘야 한다.
driver = webdriver.Chrome(path)
url = "https://cps.or.kr/safe2/cps5sub1.jsp"
driver.get(url)


df = []
for i in range(5): # 10 단위로 다음 페이지로 넘어가게끔 # range 안의 숫자는 10단위로 넘어가는 것
    ele = driver.find_element_by_xpath('/html/body/div/div[2]/div/div/div[2]/div[2]/div/table[5]/tbody/tr/td/a[10]')
    actions = ActionChains(driver)
    actions.move_to_element(ele)
    actions.click(on_element=ele)
    actions.perform()
    time.sleep(0.5)
#     '/html/body/div.body/div.main/div.container/div.row/div.col-md-9/div.row/div.col-md-12/table/tbody/a[1]'
    for j in range(3, 13): # 10(i-1) + 1~10 까지
        ele = driver.find_element_by_xpath('/html/body/div/div[2]/div/div/div[2]/div[2]/div/table[5]/tbody/tr/td/a['+ str(j)+']')
        actions = ActionChains(driver)
        actions.move_to_element(ele)
        actions.click(on_element=ele)
        actions.perform()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 from selenium.webdriver import ActionChains
# ----> 3 result = urlopen(url)
#       4 html = result.read()
#       5 soup = BeautifulSoup(html,'html.parser')
#
# NameError: name 'url' is not defined

# %% [markdown]
# ### 여기까지만 하면 돼

# %%
# 크롬 웹브라우저 실행
path = "/Users/kimsh/Downloads/chromedriver" # file 위치는 지정해줘야 한다.
driver = webdriver.Chrome(path)
url_list = []
content_list = ''
contents_list = []
 
# 해당 url 에서
# for i in range(1, 10):  # 1~300페이지까지의 블로그 내용을 읽어옴
#     url = "https://cps.or.kr/safe2/cps5sub1.jsp" # 해당 url 을 만들고
#     driver.get(url)
#     time.sleep(0.5)
    
# #     for j in range(1, 7): # 각 블로그 주소 저장
# #         titles = driver.find_element_by_xpath('/html/body/ui-view/div/main/div/div/section/div[2]/div['+str(j)+']/div/div[1]/div[1]/a[1]')
# #         title = titles.get_attribute('href')
# #         url_list.append(title)
 
# print("url 수집 끝, 해당 url 데이터 크롤링")

# %%
# selector 변경
word = 'body > div > div.main > div > div > div.col-md-9 > div.row > div > table:nth-child(12) > tbody > tr > td > a:nth-child(5)'
a = word.split('>')
word_length = len(a)
real_word = ''
i = 0
while word_length != 0:
    real_word += str(a[i])
    real_word += '/'
    i+=1
    word_length -= 1
print(real_word)

# %%
# selector 변경
word = 'body > div > div.main > div > div > div.col-md-9 > div.row > div > table:nth-child(12) > tbody > tr > td > a:nth-child(5)'
a = word.split('>')
word_length = len(a)
real_word = ''
i = 0
while word_length != 0:
    real_word += str(a[i])
    real_word += '/'
    i+=1
    word_length -= 1
print(real_word)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- Basic -->
# <meta charset="utf-8">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <title>CPS</title>
# <meta content="CPS, 스마트안전관리시스템, KTSC, 한국체육시설안전기술, 소독, 안전관리, 놀이시설, 안전교육" name="keywords"/>
# <meta content="CPS, 스마트안전관리시스템, KTSC, 한국체육시설안전기술, 소독, 안전관리, 놀이시설, 안전교육" name="description">
# <meta content="website" property="og:type">
# <meta content="CPS-한국체육시설안전기술" property="og:site_name"/>
# <meta content="CPS-한국체육시설안전기술" property="og:title">
# <meta content="CPS, 한국체육시설안전기술, 스마트안전관리시스템, KTSC" property="og:description">
# <meta content="http://www.cps.or.kr/cps.jpg" property="og:image">
# <meta content="http://www.cps.or.kr" property="og:url">
# <!-- Favicon -->
# <link href="img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="img/apple-touch-icon.png" rel="apple-touch-icon">
# <!-- Mobile Metas <meta name="viewport" content="width=device-width, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no">-->
# <meta content="width=device-width, minimum-scale=1.0, maximum-scale=1.0, user-scalable=yes" name="viewport">
# <!-- Web Fonts  -->
# <style>
#
# /*@font-face{font-family:NGB;src:url(css/font/nanumbarungothicbold.eot);src:local('dddv.ttf'),url(css/font/NanumBarunGothicBold.woff) format('woff')}
# @font-face{font-family:NG;src:url(css/font/NanumBarunGothic.eot);src:local('dddv.ttf'),url(css/font/NanumBarunGothic.woff) format('woff')} */
# @font-face{font-family:NGB;src:url(css/font/nanumbarungothicbold.eot);src:local('dddv.ttf')}
# @font-face{font-family:NG;src:url(css/font/NanumBarunGothic.eot);src:local('dddv.ttf')}
#
# </style>
# <!-- Vendor CSS -->
# <link href="vendor/bootstrap/css/bootstrap.min.css" rel="stylesheet">
# <link href="vendor/font-awesome/css/font-awesome.min.css" rel="stylesheet">
# <link href="vendor/simple-line-icons/css/simple-line-icons.min.css" rel="stylesheet">
# <link href="vendor/owl.carousel/assets/owl.carousel.min.css" rel="stylesheet">
# <link href="vendor/owl.carousel/assets/owl.theme.default.min.css" rel="stylesheet">
# <link href="vendor/magnific-popup/magnific-popup.min.css" rel="stylesheet">
# <!-- Theme CSS --><!--26-->
# <link href="css/theme5.css" rel="stylesheet">
# <link href="css/theme5-elements.css" rel="stylesheet">
# <link href="css/theme2-blog.css" rel="stylesheet">
# <link href="css/theme2-shop.css" rel="stylesheet">
# <link href="css/theme2-animate.css" rel="stylesheet">
# <!-- Skin CSS -->
# <link href="css/skins/default.css" rel="stylesheet">
# <!-- Theme Custom CSS -->
# <link href="css/custom5.css" rel="stylesheet">
# <!-- Head Libs -->
# <script src="vendor/modernizr/modernizr.min.js"></script>
# <style>
#
# 	#header .header-nav-main nav > ul > li.dropdown-mega .dropdown-mega-content {
# 		padding: 2px 3px;
# 	}
#
#
#
#
#
#
# 	#header .header-body {
# 	background: #FFf;	/*f4f4f4*/
# 	border-top: 5px solid #344257;	/*0088CC|EDEDED*/
# 	border-bottom: 1px solid transparent;	/*1px solid transparent*/
# 	padding: 0px 0;
# 	-webkit-transition: min-height 0.3s ease;
# 	-moz-transition: min-height 0.3s ease;
# 	transition: min-height 0.3s ease;
# 	width: 100%;
# 	z-index: 1001;
# 	min-height: 120px;
# }
# 	</style>
# </link></link></link></link></link></link></link></link></link></link></link></link></link></meta></link></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <!-- Vendor -->
# <script src="vendor/jquery/jquery.min.js"></script>
# <script src="vendor/jquery.appear/jquery.appear.min.js"></script>
# <script src="vendor/jquery.easing/jquery.easing.min.js"></script>
# <script src="vendor/jquery-cookie/jquery-cookie.min.js"></script>
# <script src="vendor/bootstrap/js/bootstrap.min.js"></script>
# <script src="vendor/common/common.min.js"></script>
# <script src="vendor/jquery.validation/jquery.validation.min.js"></script>
# <script src="vendor/jquery.stellar/jquery.stellar.min.js"></script>
# <script src="vendor/jquery.easy-pie-chart/jquery.easy-pie-chart.min.js"></script>
# <script src="vendor/jquery.lazyload/jquery.lazyload.min.js"></script>
# <script src="vendor/isotope/jquery.isotope.min.js"></script>
# <script src="vendor/owl.carousel/owl.carousel.min.js"></script>
# <script src="vendor/magnific-popup/jquery.magnific-popup.min.js"></script>
# <script src="vendor/vide/vide.min.js"></script>
# <body>
# <div class="body">
# <header class="header-narrow" data-plugin-options='{"stickyEnabled": true, "stickyEnableOnBoxed": true, "stickyEnableOnMobile": true, "stickyStartAt": 0, "stickySetTop": "0"}' id="header" style="min-height: 120px;">
# <div class="header-body" style="padding-bottom:2px;">
# <div class="header-top header-top-style-2">
# <div class="container">
# <p class="pull-left hidden-xs"></p>
# </div></div></div></header></div></body></html>
# <p class="pull-right" style="margin-bottom:-4px;">
# <button class="mb-xs mt-xs mr-xs btn btn-success" onclick="location.href='cps4sub1.jsp';" type="button"><i class="fa fa-cloud"></i> 스마트안전관리시스템 소개</button></p>
# <!--&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<button type="button" class="mb-xs mt-xs mr-xs btn btn-info" onclick="location.href='cps_login.jsp';"><i class="fa fa-user"></i> 로그인</button>.-->
#
#
# 							        <button class="mb-xs mt-xs mr-xs btn btn-info" onclick="location.href='https://cps.or.kr/safe2/cps_login.jsp';" type="button"><i class="fa fa-user"></i> 로그인</button>
#
#
#
# <div class="header-container container">
# <div class="header-row">
# <div class="header-column">
# <!--<div class="header-logo">
# 							<img class="pull-center img-responsive" src="img/logos/logo_new201821.png" onClick="location.href='landing2.jsp'" style="cursor:pointer;" alt="Device" >
# .-->
# <div class="header-logo" style="font-size:20px;font-weight:bold;">
# 								안전관리지원기관
#
#
# 							</div>
# </div>
# <div class="header-column">
# <div class="header-row" style="text-align:right;">
# <!--메뉴시--><div class="header-nav">
# <button class="btn header-btn-collapse-nav" data-target=".header-nav-main" data-toggle="collapse">
# <i class="fa fa-bars"></i>
# </button>
# <div class="header-nav-main header-nav-main-effect-1_ header-nav-main-sub-effect-1 collapse">
# <nav>
# <ul class="nav nav-pills" id="mainNav">
# <!--<li class="active_" style="min-width:100px;text-align:center;">
#
#
#
# 														<a class="" href="adm_main.jsp" style="font-size:15px;">
# 															<i class="fa fa-home" style="color:;font-size:17px;"></i>&nbsp;&nbsp;HOME
# 														</a>
#
#
#
#
#
# 													</li>-->
# <li class="dropdown dropdown-full-color dropdown-quaternary active_" style="text-align:center;">
# <a class="dropdown-toggle" href="#" style="font-size:15px;"><!--style="font-family: 'NGB';font-size:15px;"-->
# <i class="fa fa-shield" style="color:;font-size:15px;"></i> 기관안내
#
#
#
# 														</a>
# <ul class="dropdown-menu">
# <li><a href="cps1sub1.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  인사말</a></li>
# <li><a href="cps1sub2.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  설립목적 및 연혁</a></li>
# <li><a href="cps1sub3.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  사업소개/사회공헌</a></li>
# <li><a href="cps1sub4.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  조직도/지회현황</a></li>
# <!--<li><a href="cps1sub5.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  C.I / B.I</a></li>.-->
# <li><a href="cps1sub6.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  채용정보</a></li>
# <li><a href="cps1sub7.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  찾아오시는길</a></li>
# <li><a href="cps1sub8.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  인증현황</a></li>
# </ul>
# </li>
# <li class="dropdown dropdown-full-color dropdown-quaternary active_" style="text-align:center;">
# <a class="dropdown-toggle" href="#" style="font-size:15px;">
# <i class="fa fa-info-circle" style="color:;font-size:15px;"></i> 안전관리정책
#
# 														</a>
# <ul class="dropdown-menu">
# <li><a href="cps2sub2.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  설치검사</a></li>
# <li><a href="cps2sub4.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안전점검</a></li>
# <li><a href="cps2sub3.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  정기시설검사</a></li>
# <li><a href="cps2sub5.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안전교육</a></li>
# <!-- 2017-12-14 오후 4:47:51<li><a href="cps2sub7.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  모래소독의 중요성</a></li>
# 															<li><a href="cps2sub8.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  CPS 안심소독</a></li>
# 															<li><a href="cps2sub9.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안심소독 상담안내</a></li>
# 															<li><a href="cps2sub1.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  소독/방역 시공사례</a></li> .-->
# </ul>
# </li>
# <li class="dropdown dropdown-full-color dropdown-quaternary active_" style="text-align:center;">
# <a class="dropdown-toggle" href="#" style="font-size:15px;">
# <i class="fa fa-pie-chart" style="color:;font-size:15px;"></i> 빅데이터분석
#
# 														</a>
# <ul class="dropdown-menu">
# <li><a href="cps5sub1.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  놀이시설 현황분석</a></li>
# <li><a href="cps5sub2.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  놀이시설 안전사고 분석</a></li>
# <li><a href="cps5sub3.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  위해요소 사례 분석</a></li>
# <li><a href="cps5sub4.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  행정처분사례분석</a></li>
# <li><a href="cps5sub6.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안전사고사례분석</a></li>
# <li><a href="cps5sub5.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  놀이시설위치정보</a></li>
# </ul>
# </li>
# <li class="dropdown dropdown-full-color dropdown-quaternary active_" style="text-align:center;">
# <a class="dropdown-toggle" href="#" style="font-size:15px;">
# <i class="fa fa-desktop" style="color:;font-size:15px;"></i> 안전365센터
#
# 														</a>
# <ul class="dropdown-menu">
# <li><a href="cps6sub1.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안전자문단위촉</a></li>
# <li><a href="cps6sub2.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안전봉사단 / 신청</a></li>
# <li><a href="cps6sub3.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안전신문고제도</a></li>
# <li><a href="cps6sub4.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  무료안전컨설팅안내</a></li>
# </ul>
# </li>
# <li class="dropdown dropdown-full-color dropdown-quaternary active_" style="text-align:center;">
# <a class="dropdown-toggle" href="#" style="font-size:15px;">
# <i class="fa fa-graduation-cap" style="color:;font-size:15px;"></i> 안전교육
#
# 														</a>
# <ul class="dropdown-menu">
# <li><a href="cps7sub1.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  관리주체안전교육</a></li>
# <li><a href="cps7sub2.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  교육일정 / 신청</a></li>
# <li><a href="cps7sub5.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  교육증명서류발급</a></li>
# <li><a href="cps7sub3.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안전기술사</a></li>
# <!--<li><a href="cps6sub4.jsp"  style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  무료안전컨설팅안내</a></li>-->
# </ul>
# </li>
# <li class="dropdown dropdown-full-color dropdown-quaternary" style="text-align:center;">
# <a class="dropdown-toggle" href="#" style="font-size:15px;">
# <i class="fa fa-comment" style="color:;font-size:15px;"></i> 정보마당
#
# 														</a>
# <ul class="dropdown-menu">
# <li><a href="cps_bbs_list.jsp?BBS_ID=001" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  공지사항</a></li>
# <li><a href="cps_bbs_list.jsp?BBS_ID=002" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  보도자료/언론기고</a></li>
# <li><a href="cps8sub1.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  포토뉴스</a></li>
# <li><a href="cps_bbs_list.jsp?BBS_ID=003" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  추천놀이시설</a></li>
# <li><a href="cps8sub2.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  안전뉴스검색</a></li>
# <li><a href="cps8sub4.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  동영상자료실</a></li>
# <li><a href="cps_bbs_list.jsp?BBS_ID=009" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  법령자료</a></li>
# <li><a href="cps_bbs_list.jsp?BBS_ID=010" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  서식자료</a></li>
# <li><a href="cps_bbs_list.jsp?BBS_ID=011" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  기술자료</a></li>
# <li><a href="cps8sub3.jsp" style="font-size:14px;"><i class="fa fa-chevron-circle-right" style="color:#FFf;"></i>  FAQ</a></li>
# </ul>
# </li>
# <!--로그인-->
# <!--<li class="dropdown dropdown-mega dropdown-mega-signin signin  dropdown-full-color dropdown-quaternary" id="headerAccount" >
# 														<a class="dropdown-toggle" href="#" style="color:;font-size:15px;">
# 															<i class="fa fa-user"></i> 로그인
# 														</a>
# 														<ul class="dropdown-menu" style="color:#FFf;">
# 															<li>
# 																<div class="dropdown-mega-content">
# 																	<div class="row">
# 																		<div class="col-md-12">
#
# 																			<div class="signin-form">
#
# 																				<span class="dropdown-mega-sub-title" style="  margin-bottom: 0px; "><h4 style="color:#d1e7e7;">시스템 사용자 로그인</h4></span>
#
#
#
#
#
#
#
# 																					<div class="row">
# 																						<div class="form-group">
# 																							<div class="col-md-6 p-none">
# 																								<div style="width:90%;">
# 																								<label>ID</label>
# 																								<input type="text" id="loginid" value="" class="form-control input-lg" tabindex="1" onKeyDown="javascript:on_enterkey(this.value);">
# 																								</div>
# 																							</div>
#
# 																							<div class="col-md-6 p-none">
# 																								<label>Password</label>
# 																								<input type="password" id="loginpw" value="" class="form-control input-lg" tabindex="2" onKeyDown="javascript:on_enterkey(this.value);">
# 																							</div>
#
# 																						</div>
#
# 																					</div>
#
# 																					<div class="row">
# 																						<div class="col-md-6 pl-none">
# 																							<span class="remember-box checkbox">
# 																								<label for="autologin">
# 																									<input type="checkbox" id="autologin" name="autologin" style="width:;"> 계정정보저장
#
#
# 																								</label>
# 																							</span>
# 																						</div>
# 																						<div class="col-md-6 pr-none">
# 																							<input type="button" value="로그인" class="btn btn-default pull-right mb-xl" data-loading-text="Loading..." onClick="logincheck();">
# 																						</div>
# 																					</div>
# 																					<p class="sign-up-info_" style="color:#FFf;">부여받은 계정으로 로그인 해 주세요 </p>
#
#
#
#
#
#
#
# 																			</div>
#
#
#
#
#
# 																		</div>
# 																	</div>
# 																</div>
# 															</li>-->
# </ul>
# </nav></div></div></div></div></div></div>
# <!--로그인-->
#
#
#
#
# <!--메뉴앤디-->
#
#
#
#
#
#
# <div style="height:40px;"></div>
# <script>
# function accesspagelog() //access log page jquery save action
# {
# 	var v_url ="CPS";
# 	jQuery.ajax({
# 		type : 'POST',
# 		url : '/safe2/adm_pagelog_save.jsp',
# 		data: {  'urlkind': v_url},
# 		cache : false,
# 		async : false,
# 		error:function(request,status,error)
# 		{
#         		//alert("서버에 접속 할 수 없습니다. 잠시 후 다시 시도해 주십시오\ncode:"+request.status+"\n"+"message:"+request.responseText+"\n"+"error:"+error);
#     		},
# 		success : function(result)
# 		{
#
# 			//var v_val = jQuery.trim(result);
#
#
#
# 		}
# 	});
# }
# accesspagelog();
# </script>
# <script src="./js/highcharts4.js" type="text/javascript"></script>
# <script src="./js/highcharts4-3d.js" type="text/javascript"></script>
# <style>
# 	.zip_sel{width:96%;height:28px;};
# </style>
# <div class="main" role="main">
# <!-- ㅅㅏㅇ단 검은색 부분 -->
# <!-- 상단 검은색 앤드 -->
# <div class="container">
# <div class="row">
# <div class="col-md-3">
# <aside class="sidebar">
# <!-- 좌메뉴 -->
# <div class="heading heading-primary heading-border heading-bottom-border">
# <h1 class="heading-primary" style="font-size: 1.4em;">CATEGORIES</h1>
# </div>
# <ul class="nav nav-list mb-xlg">
# <li class="active"><a href="cps5sub1.jsp" style="color:#044796;">놀이시설현황분석</a></li>
# <li class=""><a href="cps5sub2.jsp" style="color:#;">놀이시설 안전사고분석</a></li>
# <li class=""><a href="cps5sub3.jsp" style="color:#;">위해요소 사례 분석</a></li>
# <li class=""><a href="cps5sub4.jsp" style="color:#;">행정처분사례분석</a></li>
# <li class=""><a href="cps5sub6.jsp" style="color:#;">안전사고사례분석</a></li>
# <li class=""><a href="cps5sub5.jsp" style="color:#;">놀이시설위치정보</a></li>
# <li> </li>
# <li> </li>
# </ul>
# <!-- 베너 -->
# <!--<hr>
# <h4 class="heading-primary">베너달기</h4>-->
# <!--2022-09-06 오전 11:07:03<img alt="Porto" width="260" src="images/ban_26.png" style="border:1px solid #E1E1E1">.-->
# <div style="height:18px;"></div>
# <img alt="Porto" onclick="goLand();" src="images/ban_262.png" style="border:1px solid #E1E1E1;cursor:pointer;" width="260">
# <div style="height:18px;"></div>
# <img alt="Porto" onclick="goLand2();" src="images/ban_eco2017.png" style="border:1px solid #E1E1E1;cursor:pointer;" width="260">
# <!--<div style="height:18px;"></div>
# <img alt="Porto" width="260" src="img/bnsam.png" style="border:0px solid #E1E1E1;cursor:pointer;" onClick="goCleanst();">-->
# <!--<img alt="Porto" width="260" height="67" src="images/ban_map.png" style="cursor:pointer;" onClick="ban_click();">-->
# <!--<div style="height:18px;"></div><img alt="Porto" width="260" height="67" src="images/bann2.png" style="cursor:pointer;" onClick="goLand();">-->
# <!-- <p>Nulla nunc dui, tristique in semper vel, congue sed ligula. Nam dolor ligula, faucibus id sodales in, auctor fringilla libero. Nulla nunc dui, tristique in semper vel. Nam dolor ligula, faucibus id sodales in, auctor fringilla libero. </p>-->
# <!--<br>
# <br>
# <div class="feature-box feature-box-style-3">
# 	<div class="feature-box-icon">
# 		<i class="fa fa-envelope"></i>
# 	</div>
# 	<div class="feature-box-info">
# 		<h4 class="mb-none">이메일문의</h4>
# 		<p><small>Send us an e-mail</small></p>
#
#
# 	</div>
# </div>-->
# <ul class="list list-icons list-icons-style-3 mt-xlg" style="margin-top: 10px !important;">
# <li><i class="fa fa-envelope"></i> <!--<strong>Email 문의:</strong> --><a href="cps_mail.jsp">문의사항은 Email을 이용하세요</a></li>
# </ul>
# <a href="cps_mail.jsp"> </a>
# <script>
# function ban_click()
# {
# 	//alert("베너사이트로 이동합니다");
# 	location.href="m12sub5.jsp";
# }
#
#
# function goLand()
# 									{
# 										window.open('cps4sub2.jsp', '_blank');
#
# 									}
# function goCleanst()
# {
# 	window.open('http://cps.or.kr/safe2/clean2/', '_blank');
#
#
#
# }
#
#
#
# function goLand2()
# {
# 	window.open('http://eco.cps.or.kr', '_blank');
# }
# </script>
# </img></img></aside>
# </div>
# <div class="col-md-9">
# <!-- 페이지 타이틀 -->
# <div class="heading heading-primary heading-border heading-bottom-border">
# <h1 class="heading-primary" style="font-size:2.0em;"><strong>놀이시설현황분석</strong></h1>
# </div>
# <hr class="invisible">
# <!-- 실제내용 -->
# <div class="row">
# <div class="col-md-12">
# <img alt="Device" class="pull-left img-responsive" src="images/tm1sub1.png" width="160">
# <p>전국 어린이놀이시설을 현황분석 서비스입니다. 각 지역별, 설치장소별 놀이시설을 확인하실 수 있습니다<br>
# 			※ 본 정보는 공공데이터포털(행정안전부)에서 추출된 정보이며 주기적으로 업데이트 하고 있습니다.<br>
#    (최근 업데이트 일자 : 2023-01-26)
# 					</br></br></p>
# <br><br>
# <section class="call-to-action featured featured-primary mb-xl" style="min-height: 25px;padding:6px;">
# <div class="call-to-action-content" style="width: 100%; margin-left: 1%;margin-right: 1%;padding-top: 1px;">
# <form id="search_sub" name="search_sub">
# <input name="page_index" type="hidden" value="1">
# <input name="iconval" type="hidden" value="">
# <table border="0" class="left_" style="width:100%;">
# <tr>
# <td style="width:10%;">지역검색</td>
# <td style="width:25%;style=" text-align:left;"="">
# <select class="zip_sel" name="loc_si" onchange="zip_gu(this.value);" style="">
# <option value="">선택하세요</option>
# <option value="강원">강원</option>
# <option value="경기">경기</option>
# <option value="경남">경남</option>
# <option value="경북">경북</option>
# <option value="광주">광주</option>
# <option value="대구">대구</option>
# <option value="대전">대전</option>
# <option value="부산">부산</option>
# <option value="서울">서울</option>
# <option value="세종">세종</option>
# <option value="울산">울산</option>
# <option value="인천">인천</option>
# <option value="전남">전남</option>
# <option value="전북">전북</option>
# <option value="제주">제주</option>
# <option value="충남">충남</option>
# <option value="충북">충북</option>
# </select>
# </td>
# <td style="width:25%;background:#fff;">
# <div id="loc_gu" style="width:100%;"></div>
# </td>
# <td style="width:25%;">
# <div id="loc_dg" style="width:100%;"></div>
# </td>
# <td align="center" rowspan="3">
# <button class="btn btn-primary mr-xs mb-sm" onclick="finder();" style="margin-top:14px;height:40px; " type="button">검색</button>
# </td>
# </tr>
# <tr><td style="height:9px;"></td></tr>
# <tr>
# <td style="width:10%;">상세검색</td>
# <td style="width:25%;text-align:left;">
# <select name="f_textkind" style="width:96%;height:28px;">
# <option value="2">시설명</option>
# <option value="1">시설번호</option>
# </select><input name="" style="width:1px;line-height:22px;border:none;" type="text" value="">
# </input></td>
# <td style="width:25%;">
# <input name="f_text" onkeydown="javascript:on_enterkey(this.value);" style="width:96%;line-height:22px;" type="text" value="">
# </input></td>
# <td> </td>
# </tr>
# </table>
# </input></input></form>
# </div>
# </section>
# <!-- icon -->
# <table border="0" cellpadding="4" cellspacing="1" class="left_" style="width: 100%;">
# <tr>
# <td align="center" onclick="send_icon('학교');" style="width:13%;cursor:pointer;">
# <!--
# 		<div style="color:7;background-color:#DF5647;width:90%;height:48px;"><img src="/gg/images/ico_aa.png" ></div>
# 		<div style="color:7;background-color:#DF5647;width:90%;height:20px;">학교</div>
#
#
# 		<div style="color:7;background-color:#DF5647;width:90%;height:20px;">6716</div>
# 		-->
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DF5647","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">학교</strong>
# <label>6716</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('유치원');" style="width:13%;cursor:pointer;">
# <!--
# 		<div style="color:7;background-color:#DF886B;width:90%;height:48px;"><img src="/gg/images/ico_ab.png" ></div>
# 		<div style="color:7;background-color:#DF886B;width:90%;height:20px;">유치원</div>
#
#
# 		<div style="color:7;background-color:#DF886B;width:90%;height:20px;">7530</div>
# 		-->
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DF886B","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">유치원</strong>
# <label>7530</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('도시공원');" style="width:13%;cursor:pointer;">
# <!--
# 		<div style="color:7;background-color:#D8A388;width:90%;height:48px;"><img src="/gg/images/ico_ac.png" ></div>
# 		<div style="color:7;background-color:#D8A388;width:90%;height:20px;">도시공원</div>
#
#
# 		<div style="color:7;background-color:#D8A388;width:90%;height:20px;">11355</div>
# 		-->
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#D8A388","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">도시공원</strong>
# <label>11355</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('주택단지');" style="width:13%;cursor:pointer;">
# <!--
# 		<div style="color:7;background-color:#DB712B;width:90%;height:48px;"><img src="/gg/images/ico_ad.png" ></div>
# 		<div style="color:7;background-color:#DB712B;width:90%;height:20px;">주택단지</div>
#
#
# 		<div style="color:7;background-color:#DB712B;width:90%;height:20px;">41694</div>
# 		-->
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DB712B","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">주택단지</strong>
# <label>41694</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('어린이집');" style="width:13%;cursor:pointer;">
# <!--
# 		<div style="color:7;background-color:#A9752D;width:90%;height:48px;"><img src="/gg/images/ico_ae.png" ></div>
# 		<div style="color:7;background-color:#A9752D;width:90%;height:20px;">어린이집</div>
#
#
# 		<div style="color:7;background-color:#A9752D;width:90%;height:20px;">8138</div>
# 		-->
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#A9752D","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">어린이집</strong>
# <label>8138</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('아동복지시설');" style="width:13%;cursor:pointer;">
# <!--
# 		<div style="color:7;background-color:#DAAE09;width:90%;height:48px;"><img src="/gg/images/ico_aa.png" ></div>
# 		<div style="color:7;background-color:#DAAE09;width:90%;height:20px;">아동복지시설</div>
#
#
# 		<div style="color:7;background-color:#DAAE09;width:90%;height:20px;">376</div>
# 		-->
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DAAE09","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">아동복지시설</strong>
# <label>376</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('학원');" style="width:13%;cursor:pointer;">
# <!--
# 		<div style="color:7;background-color:#DFDD6E;width:90%;height:48px;"><img src="/gg/images/ico_ab.png" ></div>
# 		<div style="color:7;background-color:#DFDD6E;width:90%;height:20px;">학원</div>
#
#
# 		<div style="color:7;background-color:#DFDD6E;width:90%;height:20px;">100</div>
# 		-->
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DFDD6E","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">학원</strong>
# <label>100</label>
# </div>
# </div>
# </td>
# </tr>
# </table>
# <table border="0" cellpadding="4" cellspacing="1" class="left_" style="width: 100%;">
# <tr>
# <td align="center" onclick="send_icon('놀이제공영업소');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#174B2D","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">놀이제공영업소</strong>
# <label>948</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('식품접객업소');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#08AE5B","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">식품접객업소</strong>
# <label>1229</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('대규모점포');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#94D374","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">대규모점포</strong>
# <label>83</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('의료기관');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#80BBA2","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">의료기관</strong>
# <label>30</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('목욕장업소');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#80BBA2","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">목욕장업소</strong>
# <label>64</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('도로휴게시설');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#80BBA2","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">도로휴게시설</strong>
# <label>34</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('주상복합');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#95B4CC","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">주상복합</strong>
# <label>258</label>
# </div>
# </div>
# </td>
# </tr>
# </table>
# <table border="0" cellpadding="4" cellspacing="1" class="left_" style="width: 100%;">
# <tr>
# <td align="center" onclick="send_icon('박물관');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DF5647","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">박물관</strong>
# <label>71</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('종교시설');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DF886B","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">종교시설</strong>
# <label>311</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('자연휴양림');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#D8A388","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">자연휴양림</strong>
# <label>109</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('하천');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DB712B","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">하천</strong>
# <label>62</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('야영장');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#A9752D","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">야영장</strong>
# <label>124</label>
# </div>
# </div>
# </td>
# <td align="center" onclick="send_icon('기타(교육청 소관)');" style="width:13%;cursor:pointer;">
# <div class="circular-bar">
# <div class="circular-bar-chart" data-percent="100" data-plugin-options='{"barColor": "#DAAE09","size": "90","lineWidth": "7"}'>
# <strong style="font-size:9pt;margin-top:-8px;">기타(교육청 소관)</strong>
# <label>0</label>
# </div>
# </div>
# </td>
# <td style="width:13%;"> </td>
# <td style="width:13%;"> </td>
# </tr>
# </table>
# <div style="height:12px;text-align:right;">Total : 79272</div>
# <br>
# <table border="0" class="table">
# <thead>
# <tr>
# <th style="text-align:center;width:9%;border-top:2px solid #2BAAB1;">시설번호</th>
# <th style="text-align:center;width:37%;border-top:2px solid #2BAAB1;">시설명</th>
# <th style="text-align:center;width:14%;border-top:2px solid #2BAAB1;">설치장소</th>
# <th style="text-align:center;width:;border-top:2px solid #2BAAB1;">주소</th>
# <th style="text-align:center;width:6%;border-top:2px solid #2BAAB1;">상세</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585992</td>
# <td style="text-align:left;vertical-align:middle;">구리인창대원칸타빌 101동</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">경기도 구리시 인창동인창동 638-1</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585992');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585964</td>
# <td style="text-align:left;vertical-align:middle;">키즈카페 동키</td>
# <td style="text-align:center;vertical-align:middle;">종교시설</td>
# <td style="text-align:left;vertical-align:middle;">부산광역시 금정구 구서동구서동 751-42, 2층</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585964');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585938</td>
# <td style="text-align:left;vertical-align:middle;">덕은한강초등학교 실외놀이시설</td>
# <td style="text-align:center;vertical-align:middle;">학교</td>
# <td style="text-align:left;vertical-align:middle;">경기도 고양시 덕양구 대덕산로 55 (덕은동)덕은한강초등학교</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585938');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585936</td>
# <td style="text-align:left;vertical-align:middle;">파주운정신도시 디에트르라포레아파트 어린이놀이터(1301동 옆)</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">경기도 파주시 산내로 89 (목동동)파주 운정신도시 디에트르라포레아파트</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585936');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585933</td>
# <td style="text-align:left;vertical-align:middle;">잼팍아트몰링하단</td>
# <td style="text-align:center;vertical-align:middle;">놀이제공영업소</td>
# <td style="text-align:left;vertical-align:middle;">부산광역시 사하구 낙동남로 1413 (하단동)12층</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585933');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585908</td>
# <td style="text-align:left;vertical-align:middle;">파인슐레 어학원</td>
# <td style="text-align:center;vertical-align:middle;">학원</td>
# <td style="text-align:left;vertical-align:middle;">울산광역시 북구 매곡산업4길 13-92 (매곡동)파인슐레 어학원</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585908');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585897</td>
# <td style="text-align:left;vertical-align:middle;">선교지구우방아이유쉘1차아파트-유아놀이터</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585897');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585896</td>
# <td style="text-align:left;vertical-align:middle;">선교지구우방아이유쉘1차아파트-어린이놀이터2</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585896');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585895</td>
# <td style="text-align:left;vertical-align:middle;">선교지구우방아이유쉘1차아파트-어린이놀이터1</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585895');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585888</td>
# <td style="text-align:left;vertical-align:middle;">경기광주역 경기행복주택 관리동</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">경기도 광주시 광주역8로 14 (역동)</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585888');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# </tbody>
# </table>
# <table style="width: 100%;">
# <tr> <td align="center" class="pagecss" colspan="9">
# <strong>1</strong>
# <a href="javascript:pagefinder(2);">2</a>
# <a href="javascript:pagefinder(3);">3</a>
# <a href="javascript:pagefinder(4);">4</a>
# <a href="javascript:pagefinder(5);">5</a>
# <a href="javascript:pagefinder(6);">6</a>
# <a href="javascript:pagefinder(7);">7</a>
# <a href="javascript:pagefinder(8);">8</a>
# <a href="javascript:pagefinder(9);">9</a>
# <a href="javascript:pagefinder(10);">10</a>
# <a class="direction next" href="javascript:pagefinder(11)">다음페이지<span></span><span></span></a>
# <a href="javascript:pagefinder(7928)">7928</a>
# </td>
# </tr>
# </table>
# <!--<span class="fa fa-search" style="font-size:17px;" ></span>-->
# </br></br></br></img></div>
# </div>
# <!-- 실제내용 앤드-->
# </hr></div>
# </div>
# </div>
# </div>
# <br><br><section class="call-to-action call-to-action-default with-button-arrow call-to-action-in-footer" style="min-height: 45px;padding:6px;background: #2a3647; ">
# <div class="container">
# <div class="row">
# <div class="col-md-12"> </div>
# </div>
# </div>
# </section>
# <footer class="short" id="footer">
# <div class="container">
# <div class="row">
# <div class="col-md-8">
# <div class="footer-copyright">
# <div class="container">
# <div class="row">
# <div class="col-md-3">
# <a class="logo" href="#">
# <span style="font-weight:bold;    font-size: 22px;">안전관리지원기관</span>
# <!--<img alt="Porto Website Template" class="img-responsive" src="img/ogo-footer2018.png">.-->
# </a>
# </div>
# <div class="col-md-9">
# <p>주소 : 경기도 화성시 동탄기흥로 614, 809호(영천동, 더퍼스트타워2차)</p>
# <p>대표전화 : 1800-6832 Fax: 02-533-8376
# 												  <i class="fa fa-envelope"></i> <a href="mailto:ksta@kstar.or.kr"> ksta@kstar.or.kr</a></p>
# <p>© Copyright 2016. KTSC All Rights Reserved.</p>
# <p>* 본 저작물은 행정안전부에서 '13년' 작성하여 공공누리 제1유형으로 개방한 전국어린이놀이놀이시설 OpenAPI을 이용하였습니다</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-md-offset-1">
# <h5 class="mb-sm">Contact Us</h5>
# <span class="phone"> 1800-6832</span>
# <!--<p class="mb-none">Fax: 02-533-8376</p>
# 							<ul class="list list-icons list-icons-sm">
# 								<li><i class="fa fa-envelope"></i> <a href="mailto:ktsc3330@hanmail.net"> ktsc3330@hanmail.net</a></li>
# 							</ul>-->
# <p class="mb-none">
# <!--<select id="selgo" style="border-radius: 0px;width:140px;background:#DFDFDF;" >
# 								<option value="">패밀리사이트</option>
# 								<option value="eco.cps.or.kr">CPS안심소독</option>
# 								<option value="gw.cps.or.kr">강원지회 홈페이지</option>
# 							</select><button type="button" class="btn btn-primary btn-xs" onclick="selgopage();" style="margin-top:0px;height:25px;">이동</button>.-->
# </p>
# </div>
# </div>
# </div>
# </footer>
# </br></br>
# <!-- Theme Base, Components and Settings -->
# <script src="js/theme.js"></script>
# <!-- Theme Custom -->
# <script src="js/custom.js"></script>
# <!-- Theme Initialization Files -->
# <script src="js/theme.init.js"></script>
#
#
# <script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#
# if(!wcs_add) var wcs_add = {};
# wcs_add["wa"] = "75c1d488280200";
# wcs_do();
# function selgopage()
# {
# 	var vg =jQuery("#selgo").val();
# 	//alert(vg );
# 	if(vg != "")
# 	{
# 		window.open("http://"+vg, '_blank');
# 	}
# }
#
#
# </script>
# <script type="text/javascript">
#
#
#
# function on_enterkey(v_sn)
# {
# 	if(event.keyCode ==13)
# 	{
# 		finder();
# 	}
# }
#
#
#
# function finder()
#
#
# {
#
#
# 	document.search_sub.iconval.value ="";
# 	document.search_sub.action="cps5sub1.jsp";
# 	document.search_sub.method="post";
#
#
# //alert("8");
# 	document.search_sub.submit();
#
# }
#
# function pagefinder(pidx)
# {
# 	document.search_sub.page_index.value =pidx;
# 	finder();
# }
#
#
# function send_icon(v_val)
# {
# 	document.search_sub.iconval.value =v_val;
# 	document.search_sub.action="cps5sub1.jsp";
# 	document.search_sub.method="post";
#
#
# 	document.search_sub.submit();
# }
#
#
# function zip_gu(locname)
# {
# 	var selval ="";
# 	jQuery.ajax({
# 		type : 'POST',
# 		url : 'zip2_gu.jsp',
# 		data: {   'locname':locname, 'selval':selval},
# 		cache : false,
# 		async : false,
# 		error:function(request,status,error)
# 		{
#         		alert("서버에 접속 할 수 없습니다. 잠시 후 다시 시도해 주십시오\ncode:"+request.status+"\n"+"message:"+request.responseText+"\n"+"error:"+error);
#
#     		},
# 		success : function(result)
# 		{
#
# 			var j_html = jQuery.trim(result);
# 			jQuery("#loc_gu").html(j_html);
# 			zip_dg("");
#
#
#
#
#
# 		}
# 	});
# }
#
#
# function zip_dg(locname)
# {
# 	var selval ="";
# 	jQuery.ajax({
# 		type : 'POST',
# 		url : 'zip2_dong.jsp',
# 		data: {   'locname':locname, 'selval':selval},
# 		cache : false,
# 		async : false,
# 		error:function(request,status,error)
# 		{
#         		alert("서버에 접속 할 수 없습니다. 잠시 후 다시 시도해 주십시오\ncode:"+request.status+"\n"+"message:"+request.responseText+"\n"+"error:"+error);
#
#     		},
# 		success : function(result)
# 		{
#
# 			var j_html = jQuery.trim(result);
# 			jQuery("#loc_dg").html(j_html);
#
#
#
#
#
#
# 		}
# 	});
# }
#
# zip_gu("");
# zip_dg("");
#
#
# /* ********************************************************
# * 상세정보 조회 팝업
# ******************************************************** */
# function fnPopDetailStep1(ciSeq){
# 	var w =750;
# 	var h =560;
# 	var winLeft = (screen.width - w ) / 2;
# 	var winTop = (screen.height- h) / 2;
# 	var settings = "toolbar=no, ";
# 	settings += "location=no, ";
# 	settings += "directories=no, ";
# 	settings += "status=no, ";
# 	settings += "menubar=no, ";
# 	settings += "scrollbars=no, ";
# 	settings += "resizable=no, ";
# 	settings += "top=" + winTop + ", ";
# 	settings += "left=" + winLeft + ", ";
# 	settings += "width=" + w + ", ";
# 	settings += "height=" + h;
# 	var url = "http://www.cpf.go.kr/front/popup/sub0101Popup1.do?ciSeq="+ciSeq;
#
#
# 	//var settings = "toolbar=no, location=no, directories=no, status=yes, menubar=no, width=680, height=500";
# 	window.open(url, 'front1', settings);
# }
# </script>

# %%
rtable = soup.find("table",{'class' : 'table'})
print(rtable)
# Out:
# <table border="0" class="table">
# <thead>
# <tr>
# <th style="text-align:center;width:9%;border-top:2px solid #2BAAB1;">시설번호</th>
# <th style="text-align:center;width:37%;border-top:2px solid #2BAAB1;">시설명</th>
# <th style="text-align:center;width:14%;border-top:2px solid #2BAAB1;">설치장소</th>
# <th style="text-align:center;width:;border-top:2px solid #2BAAB1;">주소</th>
# <th style="text-align:center;width:6%;border-top:2px solid #2BAAB1;">상세</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585992</td>
# <td style="text-align:left;vertical-align:middle;">구리인창대원칸타빌 101동</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">경기도 구리시 인창동인창동 638-1</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585992');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585964</td>
# <td style="text-align:left;vertical-align:middle;">키즈카페 동키</td>
# <td style="text-align:center;vertical-align:middle;">종교시설</td>
# <td style="text-align:left;vertical-align:middle;">부산광역시 금정구 구서동구서동 751-42, 2층</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585964');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585938</td>
# <td style="text-align:left;vertical-align:middle;">덕은한강초등학교 실외놀이시설</td>
# <td style="text-align:center;vertical-align:middle;">학교</td>
# <td style="text-align:left;vertical-align:middle;">경기도 고양시 덕양구 대덕산로 55 (덕은동)덕은한강초등학교</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585938');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585936</td>
# <td style="text-align:left;vertical-align:middle;">파주운정신도시 디에트르라포레아파트 어린이놀이터(1301동 옆)</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">경기도 파주시 산내로 89 (목동동)파주 운정신도시 디에트르라포레아파트</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585936');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585933</td>
# <td style="text-align:left;vertical-align:middle;">잼팍아트몰링하단</td>
# <td style="text-align:center;vertical-align:middle;">놀이제공영업소</td>
# <td style="text-align:left;vertical-align:middle;">부산광역시 사하구 낙동남로 1413 (하단동)12층</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585933');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585908</td>
# <td style="text-align:left;vertical-align:middle;">파인슐레 어학원</td>
# <td style="text-align:center;vertical-align:middle;">학원</td>
# <td style="text-align:left;vertical-align:middle;">울산광역시 북구 매곡산업4길 13-92 (매곡동)파인슐레 어학원</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585908');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585897</td>
# <td style="text-align:left;vertical-align:middle;">선교지구우방아이유쉘1차아파트-유아놀이터</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585897');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585896</td>
# <td style="text-align:left;vertical-align:middle;">선교지구우방아이유쉘1차아파트-어린이놀이터2</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585896');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585895</td>
# <td style="text-align:left;vertical-align:middle;">선교지구우방아이유쉘1차아파트-어린이놀이터1</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585895');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;">585888</td>
# <td style="text-align:left;vertical-align:middle;">경기광주역 경기행복주택 관리동</td>
# <td style="text-align:center;vertical-align:middle;">주택단지</td>
# <td style="text-align:left;vertical-align:middle;">경기도 광주시 광주역8로 14 (역동)</td>
# <td style="text-align:center;vertical-align:middle;">
# <a href="#" onclick="fnPopDetailStep1('585888');"><div class="feature-box feature-box-primary"><div class="feature-box-icon"><i class="fa fa-search"></i></div></div></a>
# </td></tr>
# </tbody>
# </table>

# %%
p = parser.make2d(rtable)
print(p)
# Out:
# [['시설번호', '시설명', '설치장소', '주소', '상세'], ['585992', '구리인창대원칸타빌 101동', '주택단지', '경기도 구리시 인창동인창동 638-1', ''], ['585964', '키즈카페 동키', '종교시설', '부산광역시 금정구 구서동구서동 751-42, 2층', ''], ['585938', '덕은한강초등학교 실외놀이시설', '학교', '경기도 고양시 덕양구 대덕산로 55 (덕은동)덕은한강초등학교', ''], ['585936', '파주운정신도시 디에트르라포레아파트 어린이놀이터(1301동 옆)', '주택단지', '경기도 파주시 산내로 89 (목동동)파주 운정신도시 디에트르라포레아파트', ''], ['585933', '잼팍아트몰링하단', '놀이제공영업소', '부산광역시 사하구 낙동남로 1413 (하단동)12층', ''], ['585908', '파인슐레 어학원', '학원', '울산광역시 북구 매곡산업4길 13-92 (매곡동)파인슐레 어학원', ''], ['585897', '선교지구우방아이유쉘1차아파트-유아놀이터', '주택단지', '광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)', ''], ['585896', '선교지구우방아이유쉘1차아파트-어린이놀이터2', '주택단지', '광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)', ''], ['585895', '선교지구우방아이유쉘1차아파트-어린이놀이터1', '주택단지', '광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)', ''], ['585888', '경기광주역 경기행복주택 관리동', '주택단지', '경기도 광주시 광주역8로 14 (역동)', '']]

# %%
import pandas as pd
df = pd.DataFrame(p[1:], columns = p[0])

# %%
df
# Out:
#      시설번호                                 시설명     설치장소  \
# 0  585992                      구리인창대원칸타빌 101동     주택단지
# 1  585964                             키즈카페 동키     종교시설
# 2  585938                     덕은한강초등학교 실외놀이시설       학교
# 3  585936  파주운정신도시 디에트르라포레아파트 어린이놀이터(1301동 옆)     주택단지
# 4  585933                            잼팍아트몰링하단  놀이제공영업소
# 5  585908                            파인슐레 어학원       학원
# 6  585897               선교지구우방아이유쉘1차아파트-유아놀이터     주택단지
# 7  585896             선교지구우방아이유쉘1차아파트-어린이놀이터2     주택단지
# 8  585895             선교지구우방아이유쉘1차아파트-어린이놀이터1     주택단지
# 9  585888                    경기광주역 경기행복주택 관리동     주택단지
#
#                                         주소 상세
# 0                     경기도 구리시 인창동인창동 638-1
# 1              부산광역시 금정구 구서동구서동 751-42, 2층
# 2        경기도 고양시 덕양구 대덕산로 55 (덕은동)덕은한강초등학교
# 3  경기도 파주시 산내로 89 (목동동)파주 운정신도시 디에트르라포레아파트
# 4             부산광역시 사하구 낙동남로 1413 (하단동)12층
# 5      울산광역시 북구 매곡산업4길 13-92 (매곡동)파인슐레 어학원
# 6  광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)
# 7  광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)
# 8  광주광역시 동구 선교로 38-30 (선교동, 선교1차우방아이유쉘아파트)
# 9                    경기도 광주시 광주역8로 14 (역동)

# %%
# Out:
# '#'

# %%
cnt = 0
for i in a_tag:
    cnt+=1
    if 'javascript:pagefinder(2);' == i['href']: # 두 번째
        print(cnt)
    if 'javascript:pagefinder(11)' == i['href']: # 다음 페이지
        print(cnt)
